# %%
import mglearn # 머신모델의 시각화
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.decomposition import PCA # 주성분분석
from matplotlib.colors import ListedColormap # 그래프 색깔 설정
import matplotlib.pyplot as plt
import pandas as pd
import warnings # 경고메세지 무시하려고
warnings.filterwarnings("ignore") # 경고 메세지 나오는거 무시

# %%
df = pd.read_excel("./data/Raisin_Dataset.xlsx")

# %%
df.head()
# Out:
#     Area  MajorAxisLength  MinorAxisLength  Eccentricity  ConvexArea  \
# 0  87524       442.246011       253.291155      0.819738       90546
# 1  75166       406.690687       243.032436      0.801805       78789
# 2  90856       442.267048       266.328318      0.798354       93717
# 3  45928       286.540559       208.760042      0.684989       47336
# 4  79408       352.190770       290.827533      0.564011       81463
#
#      Extent  Perimeter    Class
# 0  0.758651   1184.040  Kecimen
# 1  0.684130   1121.786  Kecimen
# 2  0.637613   1208.575  Kecimen
# 3  0.699599    844.162  Kecimen
# 4  0.792772   1073.251  Kecimen

# %%
# 건포도요?

# %%
# 독립변수와 종속변수 분리할께
x = df.drop(["Area", "Class"], axis = 1)
y = df[["Class"]]

# %%
x.head()
# Out:
#    MajorAxisLength  MinorAxisLength  Eccentricity  ConvexArea    Extent  \
# 0       442.246011       253.291155      0.819738       90546  0.758651
# 1       406.690687       243.032436      0.801805       78789  0.684130
# 2       442.267048       266.328318      0.798354       93717  0.637613
# 3       286.540559       208.760042      0.684989       47336  0.699599
# 4       352.190770       290.827533      0.564011       81463  0.792772
#
#    Perimeter
# 0   1184.040
# 1   1121.786
# 2   1208.575
# 3    844.162
# 4   1073.251

# %%
# test 데이터가 포함되어 있으면 안되나 강의편의상 MinMaxScaler(0~1) 하는 것임

# %%
mm = MinMaxScaler()
df_minmax = mm.fit_transform(x)

# %%
# 컬럼명 결합
x = pd.DataFrame(data = df_minmax, columns = x.columns)

# %%
x.head()
# Out:
#    MajorAxisLength  MinorAxisLength  Eccentricity  ConvexArea    Extent  \
# 0         0.280714         0.314376      0.767872    0.255504  0.831422
# 1         0.234638         0.284945      0.738636    0.208864  0.667854
# 2         0.280741         0.351778      0.733009    0.268084  0.565754
# 3         0.078935         0.186620      0.548194    0.084089  0.701809
# 4         0.164011         0.422064      0.350968    0.219472  0.906315
#
#    Perimeter
# 0   0.271791
# 1   0.241842
# 2   0.283594
# 3   0.108284
# 4   0.218493

# %%
x_train, x_test, y_train, y_test = train_test_split(
    x,
    y,
    test_size = 0.3,
    stratify = y,
    random_state = 31
)

# %%
len(x_train), len(x_test)
# Out:
# (630, 270)

# %%
# 기본 KNN 모델 생성 및 적용
classifier = KNeighborsClassifier(n_neighbors = 5 , 
                                    weights = "uniform",
                                    metric = "minkowski")

classifier.fit(x_train, y_train)
# Out:
# KNeighborsClassifier()

# %%
# KNN 모델 정확도 출력
print(classifier.score(x_train, y_train))
print(classifier.score(x_test, y_test))
# Out:
# 0.8841269841269841
# 0.8555555555555555

# %% [markdown]
# # k 값 조정해가면서 모델 평가해보자

# %%
k_num = range(1, 30, 2) # 홀수넣으려고

accuracies = []

for k in k_num:
    k_num_model_1 = KNeighborsClassifier(n_neighbors=k)
    k_num_model_1.fit(x_train, y_train)
    accuracies.append( 1 - k_num_model_1.score(x_test,y_test))

# %%
plt.plot(
    k_num, accuracies, "o--", color = "orange"
)
plt.xlabel("k")
plt.ylabel("Misclassification Rate")
plt.show()

# %% [markdown]
# - 성능이 5또는 7일때 성능이 가장 좋은것으로 보임

# %% [markdown]
# - 거리 가중치를 적용하지 않은 모델에서 k 이웃수를 1에서 30까지 늘려가며 KNN 모델의 오분류율을 시각화
# - 이웃 수가 5개일 때 오분류율이 가장 낮아져서 k는 5일때 가장 적합함

# %% [markdown]
# # 거리로 따졌을때

# %%
 k_num = range(1, 30, 2) # 홀수넣으려고

accuracies = []

for k in k_num:
    k_num_model_2 = KNeighborsClassifier(n_neighbors=k, weights="distance")
    k_num_model_2.fit(x_train, y_train)
    accuracies.append( 1 - k_num_model_2.score(x_test,y_test))

# %%
plt.plot(
    k_num, accuracies, "o--", color = "blue"
)
plt.xlabel("k")
plt.ylabel("Misclassification Rate")
plt.show()

# %%
k_num = range(1, 200, 2) # 홀수넣으려고

accuracies = []

for k in k_num:
    k_num_model_4 = KNeighborsClassifier(n_neighbors=k, weights="distance")
    k_num_model_4.fit(x_train, y_train)
    accuracies.append( 1 - k_num_model_4.score(x_test,y_test))


plt.plot(
    k_num, accuracies, "--", color = "blue"
)
plt.xlabel("k")
plt.ylabel("Misclassification Rate")
plt.show()

# %% [markdown]
# - 5, 7, 12 k 군집할수있는 애들이 늘어나긴했는데 나중에 모델평가할때는 어떤 차이가 있는지 모르겠으니...
# - 함 다 해봐라

# %%
 k_num = range(1, 30, 2) # 홀수넣으려고

accuracies = []

for k in k_num:
    k_num_model_3 = KNeighborsClassifier(n_neighbors=k, weights="uniform")
    k_num_model_3.fit(x_train, y_train)
    accuracies.append( 1 - k_num_model_3.score(x_test,y_test))

# %%
plt.plot(
    k_num, accuracies, "o--", color = "red"
)
plt.xlabel("k")
plt.ylabel("Misclassification Rate")
plt.show()

# %%
# 시각화를 위한 차원 축소

# 주성분 개수 설정(2개 설정)
pca = PCA(n_components = 2) # 2차원으로 압축시키겠다~~~~
df_pca = pca.fit_transform(x_test)

#print("df_pca", df_pca)
# 주성분으로 변형된 테이블 생성
df_pca = pd.DataFrame(data = df_pca, columns = ["C1","C2"])

df_pca.head()
# Out:
#          C1        C2
# 0  0.543144 -0.308078
# 1 -0.230433 -0.154572
# 2 -0.017444  0.006141
# 3 -0.130131  0.130309
# 4 -0.247548  0.057098

# %%
# 결정 경계선(decision boundary) 시각화 확인 

df_vsl_x = df_pca.to_numpy()
df_vsl_y = y_test["Class"].to_numpy()

# 그래프 설정
cmap_bold = ListedColormap(["FF0000", "#00FF00"])
fig, axes = plt.subplots(1,4, figsize = (15, 5))

# 이웃 수에 따른 결정경계 시각화
for n_neighbors, ax in zip([1,5,15,29], axes):
    k_num_model_eg = KNeighborsClassifier(n_neighbors = n_neighbors).fit(df_vsl_x, df_vsl_y)
    # 결정경계선 그려주는 명령어 : plot_2d_separator
    mglearn.plots.plot_2d_separator(k_num_model_eg, 
                                    df_vsl_x, 
                                    fill = True, 
                                    eps = 0.5, # 경계선의 영역
                                    ax = ax, alpha =0.2)

    mglearn.discrete_scatter(df_vsl_x[:,0], df_vsl_x[:,1], df_vsl_y, markeredgewidth = 0.1, c =["b", "r"], s=3, ax=ax)

    ax.set_title(f"{n_neighbors} Neighbors")

axes[0].legend(loc=3) # 첫번째만 범례표시를 하겠다~~~~
plt.show()

# %% [markdown]
# - 1 일때는 과대적합이 일어남
# - 29 일때는 과소적합이 일어남(지나친 일반화)
