# %% [markdown]
# # 데이터 분할
#
# - 머신러닝 모델의 성능을 정확하게 평가하기 위해선 훈련에 사용하지 않은 테스트 세트를 통해 평가해야함
#
# - 평가를 위한 별도의 데이터를 준비하거나 준비된 데이터 중에 일부를 떼어 테스트 세트로 준비
#
# - 훈련 : 테스트 비율 70 ~ 80 : 20 ~ 30
#     - 반드시 정해져있는건아님
#     - 전체 데이터가 아주 크고 모든 데이터를 잘 담는다? 테스트 1% 만해도 됨 ㅋㅋ

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelEncoder # 전처리 기능모두
from sklearn.neighbors import KNeighborsClassifier # 이웃알고리즘모~두 (KNN 알고리즘을 이용한 분류기)
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# %%
df = pd.read_csv("./data/Fish.csv")
df = df.loc[df["Species"].isin(["Bream", "Smelt"]), ["Species","Weight","Length2"]]

# %%
le = LabelEncoder() # 범주형의 데이터를 숫자로 바꿔줌
df["label"] = le.fit_transform(df["Species"])

# %%
df.head()
# Out:
#   Species  Weight  Length2  label
# 0   Bream   242.0     25.4      0
# 1   Bream   290.0     26.3      0
# 2   Bream   340.0     26.5      0
# 3   Bream   363.0     29.0      0
# 4   Bream   430.0     29.0      0

# %%
# train_test_split 로 데이터 분할

# %%
# 그냥 slice 해서 자르면 되는거아님?
# 아님
35 / 49
# Out:
# 0.7142857142857143

# %%
# 도미가 70퍼나있어!!!!
# 샘플링 편향이 일어나면 안된다

# %% [markdown]
# ## 샘플링 편향
#
# - 훈련 세트에 도미 데이터가 빙어 데이터가 골고루 들어가 있지 않다면 올바를게 분류할 수 없음
#
# - 데이터가 골고루 섞여있지 않으면 샘플링이 한쪽으로 치우쳤다는 의미로 샘플링 편향이라고 부

# %% [markdown]
# - train_test_split()
#     - 전달되는 리스트나 배열을 섞은 후 비율에 맞게 훈련 세트와 테스트 세트로 나누어 주는 함수
#
#     - 매개변수
#         - 첫 번째 매개변수 : 피처 데이터 세트
#             -
#         - 두 번째 매개변수 : 레이블 데이터 세트
#             -
#         - test_size
#             - 전체 데이터에서 **테스트 데이터** 세트 크기를 얼마로 샘플링할 것인가를 결정
#             - 초기값은 0.25
#         - train_size
#             - 전체 데이터에서 학습용 데이터 세트 크기를 얼마로 샘플링 할 것인가를 결정
#             - 일반적으로는 test_size 를 활용
#         - shuffle
#             -  데이터를 분리하기 전에 데이터를 미리 섞을지를 결정
#             -  초기값은 True
#             -  데이터를 분산시켜서 좀 더 효율적인 학습 및 테스트틑 데이터 세트를 만드는 데 사용
#         - random_state
#             - 매번 코드를 실행할 대마다 다른 결과가 나온다면 정확하게 모델을 평가할 수 없고 모델 최적화에 어려움이 잇음
#             - 난수를 생성할 때 특정한 규칙으로 생성해서 매번 같은 결과가 나오게 통제
#         - stratify
#             - 무작위로 데이터를 섞으면 샘플링 편향이 일어날 수 있기 때문에 **기존 데이터와 같은 비율**로 데이터를 나눌 수 있도록 할 수 있음
#
#     - 반환값
#         - 튜플 형태
#         - 학습용 데이터의 피처 데이터 세트, 테스트용 데이터의 피처 데이터 세트, 학습용 데이터의 레이블 데이터 세트, 테스트용 데이터의 레이블 데이터 세트가 순서대로 반환

# %%
x_train, x_test, y_train, y_test = train_test_split(
    df[["Length2", "Weight"]]
    , df["label"]
    , test_size = 0.25
    , stratify = df["label"]  # 비율을 맞춰줄려고 stratify 하는거임~~~~
    , random_state = 666 # 이거 본인만의 시그니처
)

# %%
print(len(x_train),len(x_test),len(y_train),len(y_test))
# Out:
# 36 13 36 13

# %%
y_test
# Out:
# 6      0
# 30     0
# 152    1
# 2      0
# 14     0
# 155    1
# 4      0
# 19     0
# 146    1
# 33     0
# 150    1
# 27     0
# 9      0
# Name: label, dtype: int64

# %%
plt.figure()
plt.scatter(x_train["Length2"],x_train["Weight"],label= "train")
plt.scatter(x_test["Length2"],x_test["Weight"],label= "test")

plt.legend()

plt.xlabel("Length")
plt.ylabel("Weight")
plt.show()

# %% [markdown]
# # 모델 훈련

# %%
knn = KNeighborsClassifier()

# %%
knn.fit(x_train, y_train)
# Out:
# KNeighborsClassifier()

# %% [markdown]
# # 모델 평가

# %%
knn.score(x_test, y_test)
# Out:
# 1.0

# %%
# 여기보세요~~~~~~~~~~~~~~~~~ 개쩌는 내 인공지능을

# %% [markdown]
# # 모델 최적화

# %%
plt.figure()

plt.scatter(x_train.iloc[:, 0], x_train.iloc[:,1])
plt.scatter(25, 150, marker = "^")

plt.xlabel("length")
plt.ylabel("Weight")
plt.show()

# %% [markdown]
# ![image.png](attachment:cdb54563-02a0-407a-b106-d512f9d98445.png)

# %%
knn.predict([[25,150]]) # 아니 빙어라고???
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but KNeighborsClassifier was fitted with feature names
#   warnings.warn(
# array([1])

# %% [markdown]
# - kneighbors()
#     - 이웃까지의 거리와 이웃 샘플의 인덱스 반환

# %%
# 길이 25, 무게 150 물고기의 이웃 데이터 확인
dist,idx = knn.kneighbors([[25,150]])
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but KNeighborsClassifier was fitted with feature names
#   warnings.warn(

# %%
plt.figure()

plt.scatter(x_train.iloc[:, 0], x_train.iloc[:,1])
plt.scatter(25, 150, marker = "^")

# idx = > 이웃한 index 들
plt.scatter(x_train.iloc[idx.flatten(),0], x_train.iloc[idx.flatten(), 1], marker = "D")

plt.xlabel("length")
plt.ylabel("Weight")
plt.show()

# %%
x_train.iloc[idx.flatten()]
# Out:
#      Length2  Weight
# 0       25.4   242.0
# 158     15.0    19.9
# 157     14.3    19.7
# 156     13.0    12.2
# 154     12.2    12.2

# %%
y_train.iloc[idx.flatten()]
# Out:
# 0      0
# 158    1
# 157    1
# 156    1
# 154    1
# Name: label, dtype: int64

# %%
print(dist)
# Out:
# [[ 92.00086956 130.48375378 130.73859415 138.32150953 138.39320793]]

# %% [markdown]
# - x축은 범위가 좁고 y 축은 범위가 넓기 때문에 y축으로 조금만 차이가 벌어져도 큰 값으로 거리가 계산됨

# %%
# x, y 축을 동일범위로 시각화

# %%
plt.figure()

plt.scatter(x_train.iloc[:, 0], x_train.iloc[:,1])
plt.scatter(25, 150, marker = "^")

# idx = > 이웃한 index 들
plt.scatter(x_train.iloc[idx.flatten(),0], x_train.iloc[idx.flatten(), 1], marker = "D")


plt.xlim(0,1000)
plt.ylim(0,1000)

plt.xlabel("length")
plt.ylabel("Weight")
plt.show()

# %% [markdown]
# ![image.png](attachment:9dc5a629-44c2-40ea-9a56-3f881d225fc2.png)

# %% [markdown]
# - 시각화 자료를 참고하면 현재 데이터에서 생선의 길이는 모델의 값을 예측하는데 거의 사용되지 않고 있음
#     - 두 독립변수의 단위가 다르기 대문에
# - kkn 은 특히 데이터 간 거리가 모델 성능에 영향을 많이주는 특성이 있음
#     - 각 독립변수의 단위가 다르면 올바른 예측이 어려울 가능성이 높음
#
# - 각 독립변수의 단위를 일정한 기준으로 맞춰주는걸 scaling 이라캄

# %% [markdown]
# # 거리기반의 모델들은 단위에 유의해야함

# %% [markdown]
# ## 스케일링
#
# - 스탠다드 스케일링(standard scaling)
#     - 각 피처값이 0에서 표준편차의 몇 배만큼 떨어져있는지를 나타내 데이터의 단위와 관계없이 동일한 조건으로 비교할 수 있게 변환
#
#     - 분산 : 데이터에서 평균을 뺀 값을 모두 **제곱**한 다음 평균을 계산
#     - 표준편차 : 분산의 제곱근, 데이터가 분산된 정도
#
#     - 평균이 0 이고 분산이 1인 가우시안 정규 분포를 가진 값으로 변환
#     - 몇몇 알고리즘에서는 데이터가 정규 분포를 가지고 있다고 가정하고 구현하기 때문에 스탠다드 스케일링 예측 성능 향상에 중요한 요소가 될 수 있음
#     - 에) 서프트 벡터 머신, 선형 회귀, 로지스틱 회귀
#
#     - 계산식
#         - (특성값 - 평균) / 표준편차 # 이상값에 매우 민감민감 ~~~
#
# - MinMaxScaler
#   - 데이터값을 0과 1사이의 범위 값으로 변환
#       - 음수 값이 있으면 -1에서 1사이의 값으로 변환
#
# - 학습 데이터와 테스트 데이터의 스케일링 변환 시 유의점
#   - scaler 객체를 이용해 데이터 스케일링 변환시 사용 메서드
#       - fit()
#           - 데이터 변환을 위한 기준 정보 설정
#           - 예) 데이터 세트이 **최댓값/최솟값** 설정 등
#
#       - transfrom()
#           - fit()으로 설정된 정보를 이용해 데이터를 변환
#
#       - fit_transform()
#           - fit() 과 transform() 을 한번에 적용
#
#       - 학습 데이터로 fit()이 적용된 스케일링 기준 정보를 그대로 테스트 데이터에 적용해야함
#
#       - **테스트 데이터로 다시 스케일링 기준 정보를 만들게 되면** 학습 데이터와 테스트 데이터의 스케일링 **기준 정보가 서로 달라지기 때문에** 올바른 예측 결과를 도출 X

# %% [markdown]
# # 훈련데이터에 대해 1번만 씀 fit 한번만!!!!!!!!

# %%
ss = StandardScaler()

# %%
scaled_train = ss.fit_transform(x_train)

# %%
scaled_train # 길이와 무게의 기준점
# Out:
# array([[-1.53681121, -1.35656576],
#        [-1.63725639, -1.35687565],
#        [-1.67743446, -1.36524271],
#        [ 0.1707568 , -0.26203019],
#        [ 0.24106843,  0.00757512],
#        [ 0.57253751,  0.78230301],
#        [ 0.77342787,  0.72032478],
#        [ 0.77342787,  0.78230301],
#        [ 0.77342787,  0.84428124],
#        [ 0.37164716,  0.1625207 ],
#        [ 1.37609893,  1.55703091],
#        [-0.19084584, -0.63699849],
#        [ 0.77342787,  0.8597758 ],
#        [ 0.42186975,  0.1625207 ],
#        [ 0.57253751,  0.78230301],
#        [ 0.87387304,  1.24713975],
#        [ 0.47209233,  0.47241185],
#        [ 0.72320528,  0.53439009],
#        [ 0.67298269,  0.73581934],
#        [ 1.22543116,  1.47955812],
#        [ 0.27120198, -0.17835958],
#        [ 0.97431822,  1.71197649],
#        [-1.23547568, -1.32526675],
#        [ 0.37164716,  0.08504791],
#        [-1.43636604, -1.34912837],
#        [ 0.6227601 ,  0.50340097],
#        [-0.10044518, -0.48825074],
# ...

# %%
# 시각화하자
# 스케일링된 데이터 시각화

# %%
plt.figure()

plt.scatter(scaled_train[:, 0], scaled_train[:,1])


plt.scatter(25, 150, marker = "^") # 테스트해보려는것도 스케일링해줘야죠

plt.xlabel("length")
plt.ylabel("Weight")
plt.show()

# %% [markdown]
# - 값의 스케일이 달라졌기 때문에 테스트 데이터도 스케일링 해주어야 함

# %%
scaled_data = ss.transform([[25,150]])
scaled_data
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# array([[-0.23102391, -0.92209836]])

# %%
# 스케일링했쥬?

# %%
plt.figure()

plt.scatter(scaled_train[:, 0], scaled_train[:,1])
# 테스트해보려는것도 스케일링해줘야죠
plt.scatter(scaled_data[0, 0],scaled_data[0, 1], marker = "^") 

plt.xlabel("length")
plt.ylabel("Weight")
plt.show()

# %% [markdown]
# # test 데이ㅓ터 스케일링

# %%
scaled_test = ss.transform(x_test)

# %%
# 스케일링 데이터로 다시 모델 훈련
knn = KNeighborsClassifier()

# %%
knn.fit(scaled_train, y_train)
# Out:
# KNeighborsClassifier()

# %%
knn.score(scaled_test, y_test)
# Out:
# 1.0

# %%
# 문제의 데이터 예측

# %%
knn.predict([[25, 150]])
# Out:
# array([0])

# %% [markdown]
# ![image.png](attachment:9158583c-ac7a-4caa-98fd-5a85ae386054.png)

# %%
dist, idx = knn.kneighbors(scaled_data)

# %%
print("dist", dist)
print("idx", idx)
# Out:
# dist [[0.28791702 0.45307236 0.77273393 0.89742867 0.91708772]]
# idx [[11 26  3 20 30]]

# %%
plt.figure()

plt.scatter(scaled_train[:, 0], scaled_train[:,1])
plt.scatter(scaled_data[0, 0],scaled_data[0, 1], marker = "^") 

# flatten 아 기억이 안나데쓰요~~~
plt.scatter(scaled_train[idx.flatten(),0], scaled_train[idx.flatten(),1], marker = "D") 

print(scaled_train[idx.flatten(),0])
print(scaled_train[idx.flatten(),1])

plt.xlabel("length")
plt.ylabel("Weight")
plt.show()
# Out:
# [-0.19084584 -0.10044518  0.1707568   0.27120198  0.47209233]
# [-0.63699849 -0.48825074 -0.26203019 -0.17835958 -0.33330516]
